# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Load Data

df=pd.read_csv('Telco_customer_churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# Dataset Description

df.describe(include='all')
# Out:
#         customerID gender  SeniorCitizen Partner Dependents       tenure  \
# count         7043   7043    7043.000000    7043       7043  7043.000000
# unique        7043      2            NaN       2          2          NaN
# top     3186-AJIEK   Male            NaN      No         No          NaN
# freq             1   3555            NaN    3641       4933          NaN
# mean           NaN    NaN       0.162147     NaN        NaN    32.371149
# std            NaN    NaN       0.368612     NaN        NaN    24.559481
# min            NaN    NaN       0.000000     NaN        NaN     0.000000
# 25%            NaN    NaN       0.000000     NaN        NaN     9.000000
# 50%            NaN    NaN       0.000000     NaN        NaN    29.000000
# 75%            NaN    NaN       0.000000     NaN        NaN    55.000000
# max            NaN    NaN       1.000000     NaN        NaN    72.000000
#
#        PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
# Data information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# Data types

df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# Missing Values

df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Duplicates

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Dataframe shape

df.shape
# Out:
# (7043, 21)

# %%
# Remove customerID column

df.drop('customerID', axis=1, inplace=True)
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
# Describe Senior citizen column

df['SeniorCitizen'].describe()
# Out:
# count    7043.000000
# mean        0.162147
# std         0.368612
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: SeniorCitizen, dtype: float64

# %%
# Convert Senior Citizen Column to categorical value Yes/No

df['SeniorCitizen'] = df['SeniorCitizen'].replace({1: 'Yes', 0: 'No'})
df.head()
# Out:
#    gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female            No     Yes         No       1           No
# 1    Male            No      No         No      34          Yes
# 2    Male            No      No         No       2          Yes
# 3    Male            No      No         No      45           No
# 4  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
# Churn value distribution plot

ax = sns.countplot(x="Churn", data=df, palette=['red', 'green'])
plt.title("Churn Distribution")

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='baseline', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %%
# Churn by gender

ax = sns.countplot(x="gender", hue="Churn", data=df, palette=['red', 'green'])
plt.title("Churn by Gender")

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='baseline', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# %%
# Churn distribution by senior citizen

ax = sns.countplot(x="SeniorCitizen", hue="Churn", data=df, palette=['red', 'green'])
plt.title("Churn Distribution by Senior Citizen")

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='baseline', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# %%
# Churn Distribution by Partners

ax = sns.countplot(x="Partner", hue="Churn", data=df, palette=['red', 'green'])
plt.title("Churn Distribution by Partners")

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='baseline', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# %%
# Churn Distribution by Dependents

ax = sns.countplot(x="Dependents", hue="Churn", data=df, palette=['red', 'green'])
plt.title("Churn Distribution by Dependents")

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='baseline', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# %%
# Churn Distribution by Contract type

ax = sns.countplot(x="Contract", hue="Churn", data=df, palette=['red', 'green'])
plt.title("Churn Distribution by Contract Type")

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='baseline', fontsize=10, color='black', xytext=(0, 5),
                textcoords='offset points')

# %%
# Churn Distribution by Monthly Charges


sns.boxplot(x="Churn", y="MonthlyCharges", data=df)
plt.title("Monthly Charges vs Churn")
plt.show()

# %%
# Churn Distribution by Total Charges

sns.boxplot(x="Churn", y="TotalCharges", data=df)
plt.title("Total Charges vs Churn")
plt.show()

# %%
# Churn Distribution by Total Charges and contract

sns.scatterplot(x="tenure", y="TotalCharges", hue="Churn", data=df)
plt.title("Tenure vs Total Charges by Churn")
plt.show()

# %%
# Churn Distribution by Internet Service

ax = sns.countplot(x="InternetService", hue="Churn", data=df, palette=['red', 'green'])
plt.title("Churn Distribution by Internet Service")
# Out:
# Text(0.5, 1.0, 'Churn Distribution by Internet Service')

# %%
# Churn vsDisrtibution by Phone Sevice

ax = sns.countplot(x="PhoneService", hue="Churn", data=df, palette=['red', 'green'])
plt.title("Churn Distribution by Phone Service")
# Out:
# Text(0.5, 1.0, 'Churn Distribution by Phone Service')

# %%
# Churn distribution by MultipleLines

ax = sns.countplot(x="MultipleLines", hue="Churn", data=df, palette=['red', 'green'])
plt.title("Churn Distribution by Multiple Lines")
# Out:
# Text(0.5, 1.0, 'Churn Distribution by Multiple Lines')

# %%
# Churn Distribution by Online Security

ax = sns.countplot(x="OnlineSecurity", hue="Churn", data=df, palette=['red', 'green'])
plt.title("Churn Distribution by Online Security")
# Out:
# Text(0.5, 1.0, 'Churn Distribution by Online Security')

# %%
# Churn distribution by online backup

ax = sns.countplot(x="OnlineBackup", hue="Churn", data=df, palette=['red', 'green'])
plt.title("Churn Distribution by Online Backup")
# Out:
# Text(0.5, 1.0, 'Churn Distribution by Online Backup')

# %%
# Churn Distribution by Device Protection

ax = sns.countplot(x="DeviceProtection", hue="Churn", data=df, palette=['red', 'green'])
plt.title("Churn Distribution by Device Protection")
# Out:
# Text(0.5, 1.0, 'Churn Distribution by Device Protection')

# %%
# Churn Distribution by Tech support

ax = sns.countplot(x="TechSupport", hue="Churn", data=df, palette=['red', 'green'])
plt.title("Churn Distribution by Online Support")
# Out:
# Text(0.5, 1.0, 'Churn Distribution by Online Support')

# %%
# Encode Categorical Variables

from sklearn.preprocessing import LabelEncoder

categorical_columns = ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
                       'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
                       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']

label_encoder = LabelEncoder()
for col in categorical_columns:
    df[col] = label_encoder.fit_transform(df[col])

# %%
# Correlation Heatmap

df_numeric = df.select_dtypes(include=["int64", "float64"])
correlation_matrix = df_numeric.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Histogram

df.hist(bins=50,figsize=(15,15))
plt.show()
